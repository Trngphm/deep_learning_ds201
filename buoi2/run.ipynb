# %% [markdown]
# # 1. leNet

# %%
! python3 main.py
# Out:
# Epoch 1:
# Loss: 2.1053
# 	- precision: 0.6232
# 	- recall: 0.6028
# 	- f1: 0.5248
#
# Đánh giá theo từng lớp (digit 0–9):
#   Digit 0: Precision=0.6435, Recall=0.9816, F1=0.7774
#   Digit 1: Precision=0.6769, Recall=0.9930, F1=0.8050
#   Digit 2: Precision=0.8043, Recall=0.6211, F1=0.7009
#   Digit 3: Precision=0.4873, Recall=0.7614, F1=0.5943
#   Digit 4: Precision=0.5835, Recall=0.7617, F1=0.6608
#   Digit 5: Precision=0.7500, Recall=0.0303, F1=0.0582
#   Digit 6: Precision=0.7223, Recall=0.8852, F1=0.7955
#   Digit 7: Precision=0.5028, Recall=0.8628, F1=0.6354
#   Digit 8: Precision=0.4167, Recall=0.0051, F1=0.0101
#   Digit 9: Precision=0.6447, Recall=0.1259, F1=0.2106
# Epoch 2:
# Loss: 1.0379
# 	- precision: 0.8265
# 	- recall: 0.8256
# 	- f1: 0.8217
#
# Đánh giá theo từng lớp (digit 0–9):
#   Digit 0: Precision=0.9084, Recall=0.9816, F1=0.9436
#   Digit 1: Precision=0.9109, Recall=0.9824, F1=0.9453
#   Digit 2: Precision=0.8535, Recall=0.8411, F1=0.8472
# ...

# %% [markdown]
# # 2. googLeNet

# %%
# !python3 main.py googlenet
# Out:
# Số lớp trong dataset: 21
#
# ===== Epoch 1/3 =====
# Loss trung bình: 2.8867
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # 3. ResNet

# %%
# !python3 main.py resnet
# Out:
# Số lớp trong dataset: 21
#
# ===== Epoch 1/3 =====
# Loss trung bình: 2.3485
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # 4. Pretrain ResNet

# %%
# !python3 main.py pretrain_resnet
# Out:
# Số lớp trong dataset: 21
#
# ===== Epoch 1/3 =====
# Loss trung bình: 2.6651
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
