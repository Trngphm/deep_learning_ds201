# %%
# !git clone https://github.com/Trngphm/deep_learning_ds201.git
# Out:
# Cloning into 'deep_learning_ds201'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 89 (delta 30), reused 81 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (89/89), 420.51 KiB | 5.32 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !cp -r /kaggle/input/phomt-data /kaggle/working/deep_learning_ds201/buoi4/data

# %%
# %cd /kaggle/working/deep_learning_ds201/buoi4
# Out:
# /kaggle/working/deep_learning_ds201/buoi4

# %%
# !python main.py --model lstm
# Out:
# ========== Epoch 1/10 ==========
# Training epoch 1: 100%|██████████| 625/625 [02:47<00:00,  3.73it/s, loss=6.3172]
# Epoch 1 - Avg Loss: 6.3172
# Evaluating: 100%|███████████████████████████████| 63/63 [00:54<00:00,  1.15it/s]
# [Dev] ROUGE-L:0.0442
#
# ========== Epoch 2/10 ==========
# Training epoch 2: 100%|██████████| 625/625 [02:48<00:00,  3.71it/s, loss=6.0650]
# Epoch 2 - Avg Loss: 6.0650
# Evaluating: 100%|███████████████████████████████| 63/63 [01:25<00:00,  1.36s/it]
# [Dev] ROUGE-L:0.0836
#
# ========== Epoch 3/10 ==========
# Training epoch 3: 100%|██████████| 625/625 [02:49<00:00,  3.69it/s, loss=5.4853]
# Epoch 3 - Avg Loss: 5.4853
# Evaluating: 100%|███████████████████████████████| 63/63 [01:10<00:00,  1.12s/it]
# [Dev] ROUGE-L:0.1024
#
# ========== Epoch 4/10 ==========
# Training epoch 4: 100%|██████████| 625/625 [02:48<00:00,  3.72it/s, loss=5.2015]
# Epoch 4 - Avg Loss: 5.2015
# Evaluating: 100%|███████████████████████████████| 63/63 [01:10<00:00,  1.11s/it]
# ...

# %%
# Neural Machine Translation by Jointly Learning to Align and Translate
# !python main.py --model lstm_attn
# Out:
# ========== Epoch 1/10 ==========
# Training epoch 1: 100%|██████████| 625/625 [05:11<00:00,  2.01it/s, loss=5.5208]
# Epoch 1 - Avg Loss: 5.5208
# Evaluating: 100%|███████████████████████████████| 63/63 [01:45<00:00,  1.67s/it]
# [Dev] ROUGE-L:0.1326
#
# ========== Epoch 2/10 ==========
# Training epoch 2: 100%|██████████| 625/625 [05:09<00:00,  2.02it/s, loss=4.8769]
# Epoch 2 - Avg Loss: 4.8769
# Evaluating: 100%|███████████████████████████████| 63/63 [01:45<00:00,  1.67s/it]
# [Dev] ROUGE-L:0.1227
#
# ========== Epoch 3/10 ==========
# Training epoch 3: 100%|██████████| 625/625 [05:11<00:00,  2.00it/s, loss=4.5241]
# Epoch 3 - Avg Loss: 4.5241
# Evaluating: 100%|███████████████████████████████| 63/63 [01:45<00:00,  1.67s/it]
# [Dev] ROUGE-L:0.1454
#
# ========== Epoch 4/10 ==========
# Training epoch 4: 100%|██████████| 625/625 [05:11<00:00,  2.01it/s, loss=4.2091]
# Epoch 4 - Avg Loss: 4.2091
# Evaluating: 100%|███████████████████████████████| 63/63 [01:45<00:00,  1.67s/it]
# ...

# %%
# Effective Approaches to Attention-based Neural Machine Translation
# !python main.py --model lstm_luong
# Out:
# ========== Epoch 1/10 ==========
# Training epoch 1: 100%|██████████| 625/625 [03:33<00:00,  2.93it/s, loss=6.2525]
# Epoch 1 - Avg Loss: 6.2525
# Evaluating: 100%|███████████████████████████████| 63/63 [01:20<00:00,  1.28s/it]
# [Dev] ROUGE-L:0.0685
#
# ========== Epoch 2/10 ==========
# Training epoch 2: 100%|██████████| 625/625 [03:30<00:00,  2.96it/s, loss=5.3982]
# Epoch 2 - Avg Loss: 5.3982
# Evaluating: 100%|███████████████████████████████| 63/63 [01:21<00:00,  1.29s/it]
# [Dev] ROUGE-L:0.1062
#
# ========== Epoch 3/10 ==========
# Training epoch 3: 100%|██████████| 625/625 [03:31<00:00,  2.96it/s, loss=5.0080]
# Epoch 3 - Avg Loss: 5.0080
# Evaluating: 100%|███████████████████████████████| 63/63 [01:21<00:00,  1.29s/it]
# [Dev] ROUGE-L:0.1199
#
# ========== Epoch 4/10 ==========
# Training epoch 4: 100%|██████████| 625/625 [03:34<00:00,  2.91it/s, loss=4.8015]
# Epoch 4 - Avg Loss: 4.8015
# Evaluating: 100%|███████████████████████████████| 63/63 [01:20<00:00,  1.29s/it]
# ...
